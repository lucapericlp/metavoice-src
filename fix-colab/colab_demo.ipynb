# %% [markdown]
# ## Installation

# %% [markdown]
# ### Clone the repository

# %%
# !git clone https://github.com/metavoiceio/metavoice-src.git
# %cd metavoice-src
# Out:
# Cloning into 'metavoice-src'...
# remote: Enumerating objects: 489, done.
# remote: Counting objects: 100% (223/223), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 489 (delta 152), reused 92 (delta 78), pack-reused 266
# Receiving objects: 100% (489/489), 19.39 MiB | 30.55 MiB/s, done.
# Resolving deltas: 100% (257/257), done.
# /content/metavoice-src/metavoice-src

# %% [markdown]
# ### Install dependencies

# %%
# !sudo apt install pipx
# !pipx install poetry
# !pipx run poetry install && pipx run poetry run pip install torch==2.2.1 torchaudio==2.2.1
# !pipx run poetry env list | sed 's/ (Activated)//' > poetry_env.txt
# NOTE: ignore any errors re pip's dependency resolver, this is a temporary dependency issue
# running the synthesise will work regardless
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pipx is already the newest version (1.0.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# 'poetry' already seems to be installed. Not modifying existing installation in
# '/root/.local/pipx/venvs/poetry'. Pass '--force' to force installation.
# Creating virtualenv fam-dgYNvpVf-py3.10 in /root/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
#
# Package operations: 147 installs, 1 update, 0 removals
#
#   - Installing attrs (23.2.0): Pending...
#   - Installing markupsafe (2.1.5): Pending...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing rpds-py (0.18.0): Pending...
#   - Installing typing-extensions (4.10.0): Pending...
#   - Installing typing-extensions (4.10.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing typing-extensions (4.10.0)
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing markupsafe (2.1.5): Pending...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing attrs (23.2.0): Installing...
#   - Installing markupsafe (2.1.5): Pending...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing markupsafe (2.1.5): Installing...
#   - Installing mpmath (1.3.0): Installing...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing attrs (23.2.0)
#   - Installing markupsafe (2.1.5)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing rpds-py (0.18.0): Installing...
#   - Installing typing-extensions (4.10.0)
#   - Installing typing-extensions (4.10.0)
#   - Installing rpds-py (0.18.0)
#   - Installing typing-extensions (4.10.0)
#   - Installing rpds-py (0.18.0)
#   - Installing typing-extensions (4.10.0)
#   - Installing mpmath (1.3.0)
#   - Installing rpds-py (0.18.0)
#   - Installing typing-extensions (4.10.0)
#   - Installing annotated-types (0.6.0): Pending...
#   - Installing catalogue (2.0.10): Pending...
#   - Installing certifi (2024.2.2): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing catalogue (2.0.10): Pending...
#   - Installing certifi (2024.2.2): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing annotated-types (0.6.0): Installing...
#   - Installing catalogue (2.0.10): Pending...
#   - Installing certifi (2024.2.2): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing certifi (2024.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0): Pending...
#   - Installing filelock (3.13.1): Pending...
#   - Installing certifi (2024.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0): Pending...
#   - Installing filelock (3.13.1): Pending...
#   - Installing catalogue (2.0.10): Installing...
#   - Installing certifi (2024.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0): Pending...
#   - Installing filelock (3.13.1): Pending...
#   - Installing catalogue (2.0.10): Installing...
#   - Installing certifi (2024.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0): Pending...
#   - Installing filelock (3.13.1): Pending...
#   - Installing annotated-types (0.6.0)
#   - Installing catalogue (2.0.10): Installing...
#   - Installing certifi (2024.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0): Pending...
#   - Installing filelock (3.13.1): Pending...
#   - Installing filelock (3.13.1): Pending...
#   - Installing exceptiongroup (1.2.0): Installing...
#   - Installing filelock (3.13.1): Pending...
#   - Installing certifi (2024.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0): Installing...
#   - Installing filelock (3.13.1): Pending...
#   - Installing catalogue (2.0.10)
#   - Installing certifi (2024.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0): Installing...
#   - Installing filelock (3.13.1): Pending...
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing filelock (3.13.1): Installing...
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing filelock (3.13.1): Installing...
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing exceptiongroup (1.2.0)
#   - Installing filelock (3.13.1): Installing...
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing idna (3.6): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0)
#   - Installing filelock (3.13.1): Installing...
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing idna (3.6): Pending...
#   - Installing certifi (2024.2.2)
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing exceptiongroup (1.2.0)
#   - Installing filelock (3.13.1): Installing...
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing idna (3.6): Pending...
#   - Installing jinja2 (3.1.3): Pending...
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing idna (3.6): Pending...
#   - Installing jinja2 (3.1.3): Pending...
#   - Installing filelock (3.13.1)
#   - Installing fsspec (2024.2.0): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing idna (3.6): Pending...
#   - Installing jinja2 (3.1.3): Pending...
#   - Installing mdurl (0.1.2): Pending...
#   - Installing idna (3.6): Pending...
#   - Installing jinja2 (3.1.3): Pending...
#   - Installing mdurl (0.1.2): Pending...
#   - Installing h11 (0.14.0): Installing...
#   - Installing idna (3.6): Pending...
#   - Installing jinja2 (3.1.3): Pending...
#   - Installing mdurl (0.1.2): Pending...
#   - Installing h11 (0.14.0): Installing...
#   - Installing idna (3.6): Pending...
#   - Installing jinja2 (3.1.3): Pending...
#   - Installing mdurl (0.1.2): Pending...
#   - Installing fsspec (2024.2.0): Installing...
#   - Installing h11 (0.14.0): Installing...
#   - Installing idna (3.6): Pending...
#   - Installing jinja2 (3.1.3): Pending...
#   - Installing mdurl (0.1.2): Pending...
#   - Installing mdurl (0.1.2): Installing...
#   - Installing mdurl (0.1.2): Installing...
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2): Installing...
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2): Installing...
#   - Installing idna (3.6): Installing...
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2): Installing...
#   - Installing exceptiongroup (1.2.0)
#   - Installing filelock (3.13.1)
#   - Installing fsspec (2024.2.0): Installing...
#   - Installing h11 (0.14.0): Installing...
#   - Installing idna (3.6): Installing...
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2): Installing...
#   - Installing charset-normalizer (3.3.2): Installing...
#   - Installing exceptiongroup (1.2.0)
#   - Installing filelock (3.13.1)
#   - Installing fsspec (2024.2.0): Installing...
#   - Installing h11 (0.14.0): Installing...
#   - Installing idna (3.6): Installing...
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2): Installing...
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing idna (3.6)
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing idna (3.6)
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing h11 (0.14.0)
#   - Installing idna (3.6)
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0): Pending...
#   - Installing referencing (0.33.0): Installing...
#   - Installing exceptiongroup (1.2.0)
#   - Installing filelock (3.13.1)
#   - Installing fsspec (2024.2.0): Installing...
#   - Installing h11 (0.14.0)
#   - Installing idna (3.6)
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0): Installing...
#   - Installing charset-normalizer (3.3.2)
#   - Installing exceptiongroup (1.2.0)
#   - Installing filelock (3.13.1)
#   - Installing fsspec (2024.2.0): Installing...
#   - Installing h11 (0.14.0)
#   - Installing idna (3.6)
#   - Installing jinja2 (3.1.3): Installing...
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0): Installing...
#   - Installing six (1.16.0): Pending...
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0): Installing...
#   - Installing six (1.16.0): Pending...
#   - Installing jinja2 (3.1.3)
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Pending...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0): Installing...
#   - Installing six (1.16.0): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0): Installing...
#   - Installing six (1.16.0): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing networkx (3.2.1): Installing...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0): Installing...
#   - Installing six (1.16.0): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing six (1.16.0): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing sympy (1.12): Pending...
#   - Installing h11 (0.14.0)
#   - Installing idna (3.6)
#   - Installing jinja2 (3.1.3)
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Installing...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing sympy (1.12): Pending...
#   - Installing fsspec (2024.2.0)
#   - Installing h11 (0.14.0)
#   - Installing idna (3.6)
#   - Installing jinja2 (3.1.3)
#   - Installing mdurl (0.1.2)
#   - Installing networkx (3.2.1): Installing...
#   - Installing pydantic-core (2.16.3): Pending...
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Pending...
#   - Installing six (1.16.0): Installing...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Pending...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Pending...
#   - Installing six (1.16.0)
#   - Installing sniffio (1.3.1): Pending...
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Pending...
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Pending...
#   - Installing sniffio (1.3.1): Installing...
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Pending...
#   - Installing urllib3 (2.2.1): Installing...
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Installing...
#   - Installing sniffio (1.3.1)
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Installing...
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0)
#   - Installing sniffio (1.3.1)
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Installing...
#   - Installing pydantic-core (2.16.3): Installing...
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0)
#   - Installing sniffio (1.3.1)
#   - Installing sympy (1.12): Pending...
#   - Installing urllib3 (2.2.1): Installing...
#   - Installing urllib3 (2.2.1)
#   - Installing urllib3 (2.2.1)
#   - Installing sympy (1.12): Installing...
#   - Installing urllib3 (2.2.1)
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0)
#   - Installing sniffio (1.3.1)
#   - Installing sympy (1.12): Installing...
#   - Installing urllib3 (2.2.1)
#   - Installing pydantic-core (2.16.3)
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0)
#   - Installing sniffio (1.3.1)
#   - Installing sympy (1.12): Installing...
#   - Installing urllib3 (2.2.1)
#   - Installing pydantic-core (2.16.3)
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0)
#   - Installing sniffio (1.3.1)
#   - Installing sympy (1.12): Installing...
#   - Installing urllib3 (2.2.1)
#   - Installing networkx (3.2.1)
#   - Installing pydantic-core (2.16.3)
#   - Installing referencing (0.33.0)
#   - Installing six (1.16.0)
#   - Installing sniffio (1.3.1)
#   - Installing sympy (1.12): Installing...
#   - Installing urllib3 (2.2.1)
#   - Installing urllib3 (2.2.1)
#   - Installing sympy (1.12)
#   - Installing urllib3 (2.2.1)
#   - Installing antlr4-python3-runtime (4.9.3): Pending...
#   - Installing anyio (4.3.0): Pending...
#   - Installing click (8.1.7): Pending...
#   - Installing cloudpickle (3.0.0): Pending...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing cloudpickle (3.0.0): Installing...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing cloudpickle (3.0.0): Installing...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing click (8.1.7): Installing...
#   - Installing cloudpickle (3.0.0): Installing...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing anyio (4.3.0): Pending...
#   - Installing click (8.1.7): Installing...
#   - Installing cloudpickle (3.0.0): Installing...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing antlr4-python3-runtime (4.9.3): Installing...
#   - Installing anyio (4.3.0): Pending...
#   - Installing click (8.1.7): Installing...
#   - Installing cloudpickle (3.0.0): Installing...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing click (8.1.7): Installing...
#   - Installing cloudpickle (3.0.0): Installing...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing anyio (4.3.0): Installing...
#   - Installing click (8.1.7): Installing...
#   - Installing cloudpickle (3.0.0): Installing...
#   - Installing cymem (2.0.8): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing cymem (2.0.8): Installing...
#   - Installing httpcore (1.0.4): Pending...
#   - Installing httpcore (1.0.4): Installing...
#   - Installing cymem (2.0.8): Installing...
#   - Installing httpcore (1.0.4): Installing...
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8): Installing...
#   - Installing httpcore (1.0.4): Installing...
#   - Installing jsonschema-specifications (2023.12.1): Pending...
#   - Installing jsonschema-specifications (2023.12.1): Installing...
#   - Installing httpcore (1.0.4): Installing...
#   - Installing jsonschema-specifications (2023.12.1): Installing...
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.4): Installing...
#   - Installing jsonschema-specifications (2023.12.1): Installing...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.4): Installing...
#   - Installing jsonschema-specifications (2023.12.1): Installing...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.4): Installing...
#   - Installing jsonschema-specifications (2023.12.1): Installing...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing murmurhash (1.0.10): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing murmurhash (1.0.10): Pending...
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing murmurhash (1.0.10): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing murmurhash (1.0.10): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing murmurhash (1.0.10): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing murmurhash (1.0.10): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing murmurhash (1.0.10): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing httpcore (1.0.4)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing murmurhash (1.0.10): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.4)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing murmurhash (1.0.10): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing anyio (4.3.0)
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.4)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing murmurhash (1.0.10): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pycparser (2.21): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pycparser (2.21): Pending...
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pycparser (2.21): Pending...
#   - Installing pydantic (2.6.3): Pending...
#   - Installing pycparser (2.21): Pending...
#   - Installing pydantic (2.6.3): Pending...
#   - Installing packaging (23.2): Installing...
#   - Installing pycparser (2.21): Pending...
#   - Installing pydantic (2.6.3): Pending...
#   - Installing pydantic (2.6.3): Pending...
#   - Installing pycparser (2.21): Installing...
#   - Installing pydantic (2.6.3): Pending...
#   - Installing pydantic (2.6.3): Installing...
#   - Installing anyio (4.3.0)
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.4)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2): Installing...
#   - Installing pycparser (2.21): Installing...
#   - Installing pydantic (2.6.3): Installing...
#   - Installing antlr4-python3-runtime (4.9.3)
#   - Installing anyio (4.3.0)
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.4)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2): Installing...
#   - Installing pycparser (2.21): Installing...
#   - Installing pydantic (2.6.3): Installing...
#   - Installing pygments (2.17.2): Pending...
#   - Installing pycparser (2.21): Installing...
#   - Installing pydantic (2.6.3): Installing...
#   - Installing pygments (2.17.2): Pending...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.21): Installing...
#   - Installing pydantic (2.6.3): Installing...
#   - Installing pygments (2.17.2): Pending...
#   - Installing python-dateutil (2.9.0.post0): Pending...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pydantic (2.6.3): Installing...
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pycparser (2.21)
#   - Installing pydantic (2.6.3): Installing...
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pytz (2024.1): Pending...
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.21)
#   - Installing pydantic (2.6.3): Installing...
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pytz (2024.1): Pending...
#   - Installing markdown-it-py (3.0.0)
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Pending...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.21)
#   - Installing pydantic (2.6.3): Installing...
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pytz (2024.1): Pending...
#   - Installing pyyaml (6.0.1): Pending...
#   - Installing pyyaml (6.0.1): Pending...
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1): Pending...
#   - Installing pyyaml (6.0.1): Installing...
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1): Installing...
#   - Installing requests (2.31.0): Pending...
#   - Installing requests (2.31.0): Installing...
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Pending...
#   - Installing srsly (2.4.8): Installing...
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1): Installing...
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Installing...
#   - Installing pydantic (2.6.3)
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1): Installing...
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Installing...
#   - Installing torch (2.1.0): Pending...
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Installing...
#   - Installing torch (2.1.0): Pending...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Installing...
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2): Pending...
#   - Installing tqdm (4.66.2): Installing...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Pending...
#   - Installing tzdata (2024.1): Installing...
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.21)
#   - Installing pydantic (2.6.3)
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing numpy (1.26.4): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.21)
#   - Installing pydantic (2.6.3)
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing tzdata (2024.1)
#   - Installing packaging (23.2)
#   - Installing pycparser (2.21)
#   - Installing pydantic (2.6.3)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing numpy (1.26.4)
#   - Installing packaging (23.2)
#   - Installing pycparser (2.21)
#   - Installing pydantic (2.6.3)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Pending...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Installing...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing blis (0.7.11): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Pending...
#   - Installing confection (0.1.4): Pending...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing cloudpathlib (0.16.0): Installing...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing cloudpathlib (0.16.0): Installing...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing cffi (1.16.0): Installing...
#   - Installing cloudpathlib (0.16.0): Installing...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Pending...
#   - Installing contourpy (1.2.0): Installing...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Installing...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.0): Installing...
#   - Installing cycler (0.12.1): Pending...
#   - Installing contourpy (1.2.0): Installing...
#   - Installing cycler (0.12.1): Pending...
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0): Installing...
#   - Installing cycler (0.12.1): Pending...
#   - Installing fonttools (4.49.0): Pending...
#   - Installing fonttools (4.49.0): Pending...
#   - Installing cycler (0.12.1): Installing...
#   - Installing fonttools (4.49.0): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0): Installing...
#   - Installing cycler (0.12.1): Installing...
#   - Installing fonttools (4.49.0): Pending...
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0): Installing...
#   - Installing cycler (0.12.1): Installing...
#   - Installing fonttools (4.49.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing cycler (0.12.1): Installing...
#   - Installing fonttools (4.49.0): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing contourpy (1.2.0)
#   - Installing cycler (0.12.1): Installing...
#   - Installing fonttools (4.49.0): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing fonttools (4.49.0): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing cycler (0.12.1)
#   - Installing fonttools (4.49.0): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing joblib (1.3.2): Pending...
#   - Installing joblib (1.3.2): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0)
#   - Installing cycler (0.12.1)
#   - Installing fonttools (4.49.0): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0)
#   - Installing cycler (0.12.1)
#   - Installing fonttools (4.49.0): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing fonttools (4.49.0): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0)
#   - Installing cycler (0.12.1)
#   - Installing fonttools (4.49.0): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing blis (0.7.11): Installing...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0)
#   - Installing cycler (0.12.1)
#   - Installing fonttools (4.49.0): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.3.2): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing omegaconf (2.3.0): Pending...
#   - Installing omegaconf (2.3.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing omegaconf (2.3.0): Installing...
#   - Installing joblib (1.3.2)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing omegaconf (2.3.0): Installing...
#   - Installing pandas (2.2.1): Pending...
#   - Installing pandas (2.2.1): Pending...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Pending...
#   - Installing pillow (10.2.0): Pending...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Pending...
#   - Installing pillow (10.2.0): Pending...
#   - Installing kiwisolver (1.4.5)
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Pending...
#   - Installing pillow (10.2.0): Pending...
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing pillow (10.2.0): Installing...
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing platformdirs (4.2.0): Installing...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Pending...
#   - Installing preshed (3.0.9): Installing...
#   - Installing preshed (3.0.9)
#   - Installing pillow (10.2.0): Installing...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pandas (2.2.1): Installing...
#   - Installing pillow (10.2.0): Installing...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2): Pending...
#   - Installing pyparsing (3.1.2): Installing...
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4): Pending...
#   - Installing retrying (1.3.4): Installing...
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1): Pending...
#   - Installing rich (13.7.1): Installing...
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Pending...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Pending...
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Pending...
#   - Updating setuptools (69.1.0 -> 69.1.1): Pending...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Installing...
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Pending...
#   - Updating setuptools (69.1.0 -> 69.1.1): Pending...
#   - Installing llvmlite (0.42.0): Installing...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Installing...
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Pending...
#   - Updating setuptools (69.1.0 -> 69.1.1): Pending...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.3.2)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5)
#   - Installing llvmlite (0.42.0): Installing...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Installing...
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Pending...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing fonttools (4.49.0)
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.3.2)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5)
#   - Installing llvmlite (0.42.0): Installing...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Installing...
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Pending...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing shellingham (1.5.4): Pending...
#   - Installing shellingham (1.5.4): Installing...
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0): Pending...
#   - Installing smart-open (6.4.0): Installing...
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3): Pending...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3): Pending...
#   - Installing scipy (1.12.0): Installing...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3): Pending...
#   - Installing starlette (0.36.3): Installing...
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1): Pending...
#   - Installing submitit (1.5.1): Installing...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0)
#   - Installing cycler (0.12.1)
#   - Installing fonttools (4.49.0)
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.3.2)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5)
#   - Installing llvmlite (0.42.0): Installing...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Installing...
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Installing...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1): Installing...
#   - Installing blis (0.7.11)
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.0)
#   - Installing cycler (0.12.1)
#   - Installing fonttools (4.49.0)
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.3.2)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5)
#   - Installing llvmlite (0.42.0): Installing...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1): Installing...
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Installing...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1): Installing...
#   - Installing threadpoolctl (3.3.0): Pending...
#   - Installing threadpoolctl (3.3.0): Installing...
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1): Pending...
#   - Installing toolz (0.12.1): Installing...
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1): Installing...
#   - Installing submitit (1.5.1)
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1): Installing...
#   - Installing torchaudio (2.1.0): Pending...
#   - Installing torchaudio (2.1.0): Pending...
#   - Installing toolz (0.12.1)
#   - Installing torchaudio (2.1.0): Pending...
#   - Installing treetable (0.2.5): Pending...
#   - Installing treetable (0.2.5): Installing...
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0): Pending...
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0): Pending...
#   - Installing torchaudio (2.1.0): Installing...
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0): Pending...
#   - Installing typer (0.9.0): Installing...
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2): Pending...
#   - Installing wasabi (1.1.2): Installing...
#   - Installing wasabi (1.1.2)
#   - Installing websockets (11.0.3): Pending...
#   - Installing websockets (11.0.3): Installing...
#   - Installing websockets (11.0.3)
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2)
#   - Installing websockets (11.0.3)
#   - Installing torchaudio (2.1.0)
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2)
#   - Installing websockets (11.0.3)
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Installing...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1)
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1)
#   - Installing torchaudio (2.1.0)
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2)
#   - Installing websockets (11.0.3)
#   - Installing pandas (2.2.1)
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Installing...
#   - Updating setuptools (69.1.0 -> 69.1.1): Installing...
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1)
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1)
#   - Installing torchaudio (2.1.0)
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2)
#   - Installing websockets (11.0.3)
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1)
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1)
#   - Installing torchaudio (2.1.0)
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2)
#   - Installing websockets (11.0.3)
#   - Updating setuptools (69.1.0 -> 69.1.1)
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1)
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1)
#   - Installing torchaudio (2.1.0)
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2)
#   - Installing websockets (11.0.3)
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1)
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Installing...
#   - Updating setuptools (69.1.0 -> 69.1.1)
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1)
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1)
#   - Installing torchaudio (2.1.0)
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2)
#   - Installing websockets (11.0.3)
#   - Installing llvmlite (0.42.0)
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.1)
#   - Installing pillow (10.2.0)
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pyparsing (3.1.2)
#   - Installing retrying (1.3.4)
#   - Installing rich (13.7.1)
#   - Installing scipy (1.12.0): Installing...
#   - Updating setuptools (69.1.0 -> 69.1.1)
#   - Installing shellingham (1.5.4)
#   - Installing smart-open (6.4.0)
#   - Installing starlette (0.36.3)
#   - Installing submitit (1.5.1)
#   - Installing threadpoolctl (3.3.0)
#   - Installing toolz (0.12.1)
#   - Installing torchaudio (2.1.0)
#   - Installing treetable (0.2.5)
#   - Installing typer (0.9.0)
#   - Installing wasabi (1.1.2)
# ...
#   - Installing transformers (4.38.2): Pending...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1): Installing...
#   - Installing transformers (4.38.2): Pending...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing spacy (3.7.4): Installing...
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1): Installing...
#   - Installing transformers (4.38.2): Pending...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing hydra-colorlog (1.2.0)
#   - Installing iniconfig (2.0.0)
#   - Installing librosa (0.10.1)
#   - Installing loguru (0.7.2)
#   - Installing num2words (0.5.13)
#   - Installing pluggy (1.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing sentencepiece (0.2.0)
#   - Installing shtab (1.7.0)
#   - Installing spacy (3.7.4): Installing...
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1): Installing...
#   - Installing transformers (4.38.2): Pending...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing gradio (4.20.1): Installing...
#   - Installing hydra-colorlog (1.2.0)
#   - Installing iniconfig (2.0.0)
#   - Installing librosa (0.10.1)
#   - Installing loguru (0.7.2)
#   - Installing num2words (0.5.13)
#   - Installing pluggy (1.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing sentencepiece (0.2.0)
#   - Installing shtab (1.7.0)
#   - Installing spacy (3.7.4): Installing...
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1): Installing...
#   - Installing transformers (4.38.2): Pending...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing transformers (4.38.2): Installing...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing deepfilterlib (0.5.6)
#   - Installing demucs (4.0.1)
#   - Installing docstring-parser (0.15)
#   - Installing encodec (0.1.1)
#   - Installing flashy (0.0.2)
#   - Installing gradio (4.20.1): Installing...
#   - Installing hydra-colorlog (1.2.0)
#   - Installing iniconfig (2.0.0)
#   - Installing librosa (0.10.1)
#   - Installing loguru (0.7.2)
#   - Installing num2words (0.5.13)
#   - Installing pluggy (1.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing sentencepiece (0.2.0)
#   - Installing shtab (1.7.0)
#   - Installing spacy (3.7.4): Installing...
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1): Installing...
#   - Installing transformers (4.38.2): Installing...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing av (11.0.0): Installing...
#   - Installing deepfilterlib (0.5.6)
#   - Installing demucs (4.0.1)
#   - Installing docstring-parser (0.15)
#   - Installing encodec (0.1.1)
#   - Installing flashy (0.0.2)
#   - Installing gradio (4.20.1): Installing...
#   - Installing hydra-colorlog (1.2.0)
#   - Installing iniconfig (2.0.0)
#   - Installing librosa (0.10.1)
#   - Installing loguru (0.7.2)
#   - Installing num2words (0.5.13)
#   - Installing pluggy (1.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing sentencepiece (0.2.0)
#   - Installing shtab (1.7.0)
#   - Installing spacy (3.7.4): Installing...
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1): Installing...
#   - Installing transformers (4.38.2): Installing...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing transformers (4.38.2): Installing...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing torchmetrics (1.3.1)
#   - Installing transformers (4.38.2): Installing...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1)
#   - Installing transformers (4.38.2): Installing...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing spacy (3.7.4)
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1)
#   - Installing transformers (4.38.2): Installing...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing transformers (4.38.2)
#   - Installing xformers (0.0.22.post7): Pending...
#   - Installing xformers (0.0.22.post7): Installing...
#   - Installing hydra-colorlog (1.2.0)
#   - Installing iniconfig (2.0.0)
#   - Installing librosa (0.10.1)
#   - Installing loguru (0.7.2)
#   - Installing num2words (0.5.13)
#   - Installing pluggy (1.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing sentencepiece (0.2.0)
#   - Installing shtab (1.7.0)
#   - Installing spacy (3.7.4)
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1)
#   - Installing transformers (4.38.2)
#   - Installing xformers (0.0.22.post7): Installing...
#   - Installing gradio (4.20.1)
#   - Installing hydra-colorlog (1.2.0)
#   - Installing iniconfig (2.0.0)
#   - Installing librosa (0.10.1)
#   - Installing loguru (0.7.2)
#   - Installing num2words (0.5.13)
#   - Installing pluggy (1.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing sentencepiece (0.2.0)
#   - Installing shtab (1.7.0)
#   - Installing spacy (3.7.4)
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1)
#   - Installing transformers (4.38.2)
#   - Installing xformers (0.0.22.post7): Installing...
#   - Installing deepfilterlib (0.5.6)
#   - Installing demucs (4.0.1)
#   - Installing docstring-parser (0.15)
#   - Installing encodec (0.1.1)
#   - Installing flashy (0.0.2)
#   - Installing gradio (4.20.1)
#   - Installing hydra-colorlog (1.2.0)
#   - Installing iniconfig (2.0.0)
#   - Installing librosa (0.10.1)
#   - Installing loguru (0.7.2)
#   - Installing num2words (0.5.13)
#   - Installing pluggy (1.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing sentencepiece (0.2.0)
#   - Installing shtab (1.7.0)
#   - Installing spacy (3.7.4)
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1)
#   - Installing transformers (4.38.2)
#   - Installing xformers (0.0.22.post7): Installing...
#   - Installing av (11.0.0)
#   - Installing deepfilterlib (0.5.6)
#   - Installing demucs (4.0.1)
#   - Installing docstring-parser (0.15)
#   - Installing encodec (0.1.1)
#   - Installing flashy (0.0.2)
#   - Installing gradio (4.20.1)
#   - Installing hydra-colorlog (1.2.0)
#   - Installing iniconfig (2.0.0)
#   - Installing librosa (0.10.1)
#   - Installing loguru (0.7.2)
#   - Installing num2words (0.5.13)
#   - Installing pluggy (1.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing sentencepiece (0.2.0)
#   - Installing shtab (1.7.0)
#   - Installing spacy (3.7.4)
#   - Installing tomli (2.0.1)
#   - Installing torchmetrics (1.3.1)
#   - Installing transformers (4.38.2)
#   - Installing xformers (0.0.22.post7): Installing...
#   - Installing xformers (0.0.22.post7)
#   - Installing audiocraft (1.2.0): Pending...
#   - Installing deepfilternet (0.5.6): Pending...
#   - Installing ninja (1.11.1.1): Pending...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing pytest (8.0.2): Pending...
#   - Installing tyro (0.7.3): Pending...
#   - Installing ninja (1.11.1.1): Pending...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing pytest (8.0.2): Pending...
#   - Installing tyro (0.7.3): Pending...
#   - Installing deepfilternet (0.5.6): Installing...
#   - Installing ninja (1.11.1.1): Pending...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing pytest (8.0.2): Pending...
#   - Installing tyro (0.7.3): Pending...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing pytest (8.0.2): Pending...
#   - Installing tyro (0.7.3): Pending...
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing pytest (8.0.2): Pending...
#   - Installing tyro (0.7.3): Pending...
#   - Installing tyro (0.7.3): Installing...
#   - Installing tyro (0.7.3): Installing...
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3): Installing...
#   - Installing deepfilternet (0.5.6): Installing...
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3): Installing...
#   - Installing audiocraft (1.2.0): Installing...
#   - Installing deepfilternet (0.5.6): Installing...
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3): Installing...
#   - Installing tyro (0.7.3)
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3)
#   - Installing tiktoken (0.5.1): Installing...
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3)
#   - Installing tiktoken (0.5.1): Installing...
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3)
#   - Installing ninja (1.11.1.1)
#   - Installing tiktoken (0.5.1): Installing...
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3)
#   - Installing ninja (1.11.1.1)
#   - Installing tiktoken (0.5.1): Installing...
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3)
#   - Installing deepfilternet (0.5.6)
#   - Installing ninja (1.11.1.1)
#   - Installing tiktoken (0.5.1): Installing...
#   - Installing pytest (8.0.2): Installing...
#   - Installing tyro (0.7.3)
#   - Installing tyro (0.7.3)
#   - Installing pytest (8.0.2)
#   - Installing tyro (0.7.3)
# Installing /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages/tests/__init__.py over existing file
#   - Installing deepfilternet (0.5.6)
#   - Installing ninja (1.11.1.1)
#   - Installing tiktoken (0.5.1): Installing...
#   - Installing pytest (8.0.2)
#   - Installing tyro (0.7.3)
#   - Installing audiocraft (1.2.0)
#   - Installing deepfilternet (0.5.6)
#   - Installing ninja (1.11.1.1)
#   - Installing tiktoken (0.5.1): Installing...
#   - Installing pytest (8.0.2)
#   - Installing tyro (0.7.3)
#   - Installing pytest (8.0.2)
#   - Installing tyro (0.7.3)
#   - Installing tiktoken (0.5.1)
#   - Installing pytest (8.0.2)
#   - Installing tyro (0.7.3)
#
# Installing the current project: fam (0.1.0)Installing the current project: fam (0.1.0)
# Collecting torch==2.2.1
#   Using cached torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchaudio==2.2.1
#   Using cached torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (4.10.0)
# Requirement already satisfied: sympy in /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (1.12)
# Requirement already satisfied: networkx in /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (3.2.1)
# Requirement already satisfied: jinja2 in /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (3.1.3)
# Requirement already satisfied: fsspec in /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (2024.2.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.1)
#   Using cached triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1)
#   Using cached nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages (from jinja2->torch==2.2.1) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages (from sympy->torch==2.2.1) (1.3.0)
# Using cached torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
# Using cached torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
# Using cached nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0
#     Uninstalling torch-2.1.0:
#       Successfully uninstalled torch-2.1.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.1.0
#     Uninstalling torchaudio-2.1.0:
#       Successfully uninstalled torchaudio-2.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# audiocraft 1.2.0 requires torch==2.1.0, but you have torch 2.2.1 which is incompatible.
# xformers 0.0.22.post7 requires torch==2.1.0, but you have torch 2.2.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 torch-2.2.1 torchaudio-2.2.1 triton-2.2.0

# %%
import sys, pathlib
venv = pathlib.Path("poetry_env.txt").read_text().strip("\n")
sys.path.append(f"/root/.cache/pypoetry/virtualenvs/{venv}/lib/python3.10/site-packages")

# %% [markdown]
# ## Inference

# %%
from IPython.display import Audio, display
from fam.llm.fast_inference import TTS

tts = TTS()
# Out:
# WARNING:xformers:WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.1.0+cu121 with CUDA 1201 (you have 2.2.1+cu121)
#     Python  3.10.13 (you have 3.10.12)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/809 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/93.1M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# mbd_comp_8.pt:   0%|          | 0.00/4.58G [00:00<?, ?B/s]
# /root/.cache/pypoetry/virtualenvs/fam-dgYNvpVf-py3.10/lib/python3.10/site-packages/df/io.py:9: UserWarning: `torchaudio.backend.common.AudioMetaData` has been moved to `torchaudio.AudioMetaData`. Please update the import path.
#   from torchaudio.backend.common import AudioMetaData
# using dtype=float16
# using dtype=float16
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/2.68k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# first_stage.pt:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# second_stage.pt:   0%|          | 0.00/57.9M [00:00<?, ?B/s]
# speaker_encoder.pt:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# number of parameters: 14.07M
# 2024-03-24 12:53:38 | INFO     | DF | Running on torch 2.2.1+cu121
# 2024-03-24 12:53:38 | INFO     | DF | Running on host 1412489c2016
# 2024-03-24 12:53:38 | INFO     | DF | Loading model settings of DeepFilterNet3
# 2024-03-24 12:53:38 | INFO     | DF | Using DeepFilterNet3 model at /root/.cache/DeepFilterNet/DeepFilterNet3
# 2024-03-24 12:53:38 | INFO     | DF | Initializing model `deepfilternet3`
# 2024-03-24 12:53:38 | INFO     | DF | Found checkpoint /root/.cache/DeepFilterNet/DeepFilterNet3/checkpoints/model_120.ckpt.best with epoch 120
# 2024-03-24 12:53:38 | INFO     | DF | Running on device cpu
# 2024-03-24 12:53:38 | INFO     | DF | Model loaded
# Using device=cpu
# Loading model ...
# using dtype=float16
# Time to load model: 27.51 seconds
# Compiling...Can take up to 2 mins.
# ---------------------------------------------------------------------------
# TorchRuntimeError                         Traceback (most recent call last)
# <ipython-input-6-1ac00c833092> in <cell line: 4>()
#       2 from fam.llm.fast_inference import TTS
#       3
# ----> 4 tts = TTS()
#
# /content/metavoice-src/metavoice-src/fam/llm/fast_inference.py in __init__(self, model_name, seed, output_dir, quantisation_mode)
#      84
#      85         self.precision = {"float16": torch.float16, "bfloat16": torch.bfloat16}[self._dtype]
# ---> 86         self.model, self.tokenizer, self.smodel, self.model_size = build_model(
#      87             precision=self.precision,
#      88             checkpoint_path=Path(f"{self._model_dir}/first_stage.pt"),
#
# /content/metavoice-src/metavoice-src/fam/llm/fast_inference_utils.py in build_model(precision, checkpoint_path, spk_emb_ckpt_path, compile_prefill, compile, device, quantisation_mode)
#     373     device_sync(device=device)  # MKG
#     374     t0 = time.perf_counter()
# --> 375     y = generate(
#     376         model,
#     377         encoded,
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /content/metavoice-src/metavoice-src/fam/llm/fast_inference_utils.py in generate(model, prompt, spk_emb, max_new_tokens, callback, end_of_audio_token, **sampling_kwargs)
#     209     input_pos = torch.arange(0, T, device=device)
#     210
# --> 211     next_token = prefill(model, prompt.view(1, -1).repeat(2, 1), spk_emb, input_pos, **sampling_kwargs)
#     212     seq = torch.cat([seq, next_token.view(1)])
#     213
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py in _fn(*args, **kwargs)
#     487                 dynamo_config_ctx.__enter__()
#     488             try:
# --> 489                 return fn(*args, **kwargs)
#     490             finally:
#     491                 set_eval_frame(prior)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py in catch_errors(frame, cache_entry, frame_state)
#     653
#     654         with compile_lock, _disable_current_modes():
# --> 655             return callback(frame, cache_entry, hooks, frame_state)
#     656
#     657     catch_errors._torchdynamo_orig_callable = callback  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py in _convert_frame_assert(frame, cache_entry, hooks, frame_state)
#     381
#     382         with config.patch(_patch_config_if_changed()):
# --> 383             compiled_product = _compile(
#     384                 frame.f_code,
#     385                 frame.f_globals,
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id)
#     644     with compile_context(CompileContext(compile_id)):
#     645         try:
# --> 646             guarded_code = compile_inner(code, one_graph, hooks, transform)
#     647             return guarded_code
#     648         except (
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py in time_wrapper(*args, **kwargs)
#     242             with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     243                 t0 = time.time()
# --> 244                 r = func(*args, **kwargs)
#     245                 time_spent = time.time() - t0
#     246             compilation_time_metrics[key].append(time_spent)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py in compile_inner(code, one_graph, hooks, transform)
#     560             CompileContext.get().attempt = attempt
#     561             try:
# --> 562                 out_code = transform_code_object(code, transform)
#     563                 break
#     564             except exc.RestartAnalysis as e:
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py in transform_code_object(code, transformations, safe)
#    1031     propagate_line_nums(instructions)
#    1032
# -> 1033     transformations(instructions, code_options)
#    1034     return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#    1035
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py in _fn(*args, **kwargs)
#     149         cleanup = setup_compile_debug()
#     150         try:
# --> 151             return fn(*args, **kwargs)
#     152         finally:
#     153             cleanup.close()
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py in transform(instructions, code_options)
#     525         try:
#     526             with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 527                 tracer.run()
#     528         except exc.UnspecializeRestartAnalysis:
#     529             speculation_log.clear()
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in run(self)
#    2126
#    2127     def run(self):
# -> 2128         super().run()
#    2129
#    2130     def match_nested_cell(self, name, cell):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     816                     self.instruction_pointer is not None
#     817                     and not self.output.should_exit
# --> 818                     and self.step()
#     819                 ):
#     820                     pass
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     779                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     780             )
# --> 781             getattr(self, inst.opname)(inst)
#     782
#     783             return inst.opname != "RETURN_VALUE"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     468                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     469                 )
# --> 470                 return inner_fn(self, inst)
#     471             except Unsupported as excp:
#     472                 if self.should_compile_partial_graph() and self.has_backedge():
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION(self, inst)
#    1211         args = self.popn(inst.argval)
#    1212         fn = self.pop()
# -> 1213         self.call_function(fn, args, {})
#    1214
#    1215     @break_graph_if_unsupported(push=1)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     650         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     651             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 652         self.push(fn.call_function(self, args, kwargs))
#     653
#     654     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/lazy.py in realize_and_forward(self, *args, **kwargs)
#      88     @functools.wraps(getattr(VariableTracker, name))
#      89     def realize_and_forward(self, *args, **kwargs):
# ---> 90         return getattr(self.realize(), name)(*args, **kwargs)
#      91
#      92     return realize_and_forward
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/nn_module.py in call_function(self, tx, args, kwargs)
#     326                 else:
#     327                     assert istype(fn, types.FunctionType)
# --> 328                 return tx.inline_user_function_return(
#     329                     variables.UserFunctionVariable(fn, source=fn_source),
#     330                     args,
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_user_function_return(self, fn, args, kwargs)
#     686         A call to some user defined function by inlining it.
#     687         """
# --> 688         return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#     689
#     690     def get_line_of_code_header(self, lineno=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call(cls, parent, func, args, kwargs)
#    2259     def inline_call(cls, parent, func, args, kwargs):
#    2260         with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2261             return cls.inline_call_(parent, func, args, kwargs)
#    2262
#    2263     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call_(parent, func, args, kwargs)
#    2374         try:
#    2375             with strict_ctx:
# -> 2376                 tracer.run()
#    2377         except exc.SkipFrame as e:
#    2378             msg = f"SKIPPED INLINING {code}: {e}"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     816                     self.instruction_pointer is not None
#     817                     and not self.output.should_exit
# --> 818                     and self.step()
#     819                 ):
#     820                     pass
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     779                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     780             )
# --> 781             getattr(self, inst.opname)(inst)
#     782
#     783             return inst.opname != "RETURN_VALUE"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     468                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     469                 )
# --> 470                 return inner_fn(self, inst)
#     471             except Unsupported as excp:
#     472                 if self.should_compile_partial_graph() and self.has_backedge():
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION_EX(self, inst)
#    1250             unimplemented(f"non-static call {typestr(argsvars)} {typestr(kwargsvars)}")
#    1251
# -> 1252         self.call_function(fn, argsvars.items, kwargsvars.items)
#    1253
#    1254     @break_graph_if_unsupported(push=1)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     650         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     651             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 652         self.push(fn.call_function(self, args, kwargs))
#     653
#     654     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#     292                     tx, self.fn.__name__, args, kwargs, constant=self.is_constant
#     293                 )
# --> 294         return super().call_function(tx, args, kwargs)
#     295
#     296     def inspect_parameter_names(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#     246             )
#     247
# --> 248         return super().call_function(tx, args, kwargs)
#     249
#     250
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#      79         self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#      80     ) -> "VariableTracker":
# ---> 81         return tx.inline_user_function_return(
#      82             self, list(self.self_args()) + list(args), kwargs
#      83         )
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_user_function_return(self, fn, args, kwargs)
#     686         A call to some user defined function by inlining it.
#     687         """
# --> 688         return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#     689
#     690     def get_line_of_code_header(self, lineno=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call(cls, parent, func, args, kwargs)
#    2259     def inline_call(cls, parent, func, args, kwargs):
#    2260         with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2261             return cls.inline_call_(parent, func, args, kwargs)
#    2262
#    2263     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call_(parent, func, args, kwargs)
#    2374         try:
#    2375             with strict_ctx:
# -> 2376                 tracer.run()
#    2377         except exc.SkipFrame as e:
#    2378             msg = f"SKIPPED INLINING {code}: {e}"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     816                     self.instruction_pointer is not None
#     817                     and not self.output.should_exit
# --> 818                     and self.step()
#     819                 ):
#     820                     pass
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     779                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     780             )
# --> 781             getattr(self, inst.opname)(inst)
#     782
#     783             return inst.opname != "RETURN_VALUE"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     468                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     469                 )
# --> 470                 return inner_fn(self, inst)
#     471             except Unsupported as excp:
#     472                 if self.should_compile_partial_graph() and self.has_backedge():
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION(self, inst)
#    1211         args = self.popn(inst.argval)
#    1212         fn = self.pop()
# -> 1213         self.call_function(fn, args, {})
#    1214
#    1215     @break_graph_if_unsupported(push=1)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     650         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     651             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 652         self.push(fn.call_function(self, args, kwargs))
#     653
#     654     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/nn_module.py in call_function(self, tx, args, kwargs)
#     326                 else:
#     327                     assert istype(fn, types.FunctionType)
# --> 328                 return tx.inline_user_function_return(
#     329                     variables.UserFunctionVariable(fn, source=fn_source),
#     330                     args,
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_user_function_return(self, fn, args, kwargs)
#     686         A call to some user defined function by inlining it.
#     687         """
# --> 688         return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#     689
#     690     def get_line_of_code_header(self, lineno=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call(cls, parent, func, args, kwargs)
#    2259     def inline_call(cls, parent, func, args, kwargs):
#    2260         with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2261             return cls.inline_call_(parent, func, args, kwargs)
#    2262
#    2263     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call_(parent, func, args, kwargs)
#    2374         try:
#    2375             with strict_ctx:
# -> 2376                 tracer.run()
#    2377         except exc.SkipFrame as e:
#    2378             msg = f"SKIPPED INLINING {code}: {e}"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     816                     self.instruction_pointer is not None
#     817                     and not self.output.should_exit
# --> 818                     and self.step()
#     819                 ):
#     820                     pass
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     779                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     780             )
# --> 781             getattr(self, inst.opname)(inst)
#     782
#     783             return inst.opname != "RETURN_VALUE"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     468                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     469                 )
# --> 470                 return inner_fn(self, inst)
#     471             except Unsupported as excp:
#     472                 if self.should_compile_partial_graph() and self.has_backedge():
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION_EX(self, inst)
#    1250             unimplemented(f"non-static call {typestr(argsvars)} {typestr(kwargsvars)}")
#    1251
# -> 1252         self.call_function(fn, argsvars.items, kwargsvars.items)
#    1253
#    1254     @break_graph_if_unsupported(push=1)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     650         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     651             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 652         self.push(fn.call_function(self, args, kwargs))
#     653
#     654     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#     292                     tx, self.fn.__name__, args, kwargs, constant=self.is_constant
#     293                 )
# --> 294         return super().call_function(tx, args, kwargs)
#     295
#     296     def inspect_parameter_names(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#     246             )
#     247
# --> 248         return super().call_function(tx, args, kwargs)
#     249
#     250
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#      79         self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#      80     ) -> "VariableTracker":
# ---> 81         return tx.inline_user_function_return(
#      82             self, list(self.self_args()) + list(args), kwargs
#      83         )
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_user_function_return(self, fn, args, kwargs)
#     686         A call to some user defined function by inlining it.
#     687         """
# --> 688         return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#     689
#     690     def get_line_of_code_header(self, lineno=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call(cls, parent, func, args, kwargs)
#    2259     def inline_call(cls, parent, func, args, kwargs):
#    2260         with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2261             return cls.inline_call_(parent, func, args, kwargs)
#    2262
#    2263     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call_(parent, func, args, kwargs)
#    2374         try:
#    2375             with strict_ctx:
# -> 2376                 tracer.run()
#    2377         except exc.SkipFrame as e:
#    2378             msg = f"SKIPPED INLINING {code}: {e}"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     816                     self.instruction_pointer is not None
#     817                     and not self.output.should_exit
# --> 818                     and self.step()
#     819                 ):
#     820                     pass
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     779                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     780             )
# --> 781             getattr(self, inst.opname)(inst)
#     782
#     783             return inst.opname != "RETURN_VALUE"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     468                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     469                 )
# --> 470                 return inner_fn(self, inst)
#     471             except Unsupported as excp:
#     472                 if self.should_compile_partial_graph() and self.has_backedge():
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION(self, inst)
#    1211         args = self.popn(inst.argval)
#    1212         fn = self.pop()
# -> 1213         self.call_function(fn, args, {})
#    1214
#    1215     @break_graph_if_unsupported(push=1)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     650         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     651             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 652         self.push(fn.call_function(self, args, kwargs))
#     653
#     654     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/nn_module.py in call_function(self, tx, args, kwargs)
#     326                 else:
#     327                     assert istype(fn, types.FunctionType)
# --> 328                 return tx.inline_user_function_return(
#     329                     variables.UserFunctionVariable(fn, source=fn_source),
#     330                     args,
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_user_function_return(self, fn, args, kwargs)
#     686         A call to some user defined function by inlining it.
#     687         """
# --> 688         return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#     689
#     690     def get_line_of_code_header(self, lineno=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call(cls, parent, func, args, kwargs)
#    2259     def inline_call(cls, parent, func, args, kwargs):
#    2260         with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2261             return cls.inline_call_(parent, func, args, kwargs)
#    2262
#    2263     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call_(parent, func, args, kwargs)
#    2374         try:
#    2375             with strict_ctx:
# -> 2376                 tracer.run()
#    2377         except exc.SkipFrame as e:
#    2378             msg = f"SKIPPED INLINING {code}: {e}"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     816                     self.instruction_pointer is not None
#     817                     and not self.output.should_exit
# --> 818                     and self.step()
#     819                 ):
#     820                     pass
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     779                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     780             )
# --> 781             getattr(self, inst.opname)(inst)
#     782
#     783             return inst.opname != "RETURN_VALUE"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     468                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     469                 )
# --> 470                 return inner_fn(self, inst)
#     471             except Unsupported as excp:
#     472                 if self.should_compile_partial_graph() and self.has_backedge():
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION_EX(self, inst)
#    1250             unimplemented(f"non-static call {typestr(argsvars)} {typestr(kwargsvars)}")
#    1251
# -> 1252         self.call_function(fn, argsvars.items, kwargsvars.items)
#    1253
#    1254     @break_graph_if_unsupported(push=1)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     650         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     651             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 652         self.push(fn.call_function(self, args, kwargs))
#     653
#     654     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#     292                     tx, self.fn.__name__, args, kwargs, constant=self.is_constant
#     293                 )
# --> 294         return super().call_function(tx, args, kwargs)
#     295
#     296     def inspect_parameter_names(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#     246             )
#     247
# --> 248         return super().call_function(tx, args, kwargs)
#     249
#     250
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#      79         self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#      80     ) -> "VariableTracker":
# ---> 81         return tx.inline_user_function_return(
#      82             self, list(self.self_args()) + list(args), kwargs
#      83         )
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_user_function_return(self, fn, args, kwargs)
#     686         A call to some user defined function by inlining it.
#     687         """
# --> 688         return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#     689
#     690     def get_line_of_code_header(self, lineno=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call(cls, parent, func, args, kwargs)
#    2259     def inline_call(cls, parent, func, args, kwargs):
#    2260         with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2261             return cls.inline_call_(parent, func, args, kwargs)
#    2262
#    2263     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in inline_call_(parent, func, args, kwargs)
#    2374         try:
#    2375             with strict_ctx:
# -> 2376                 tracer.run()
#    2377         except exc.SkipFrame as e:
#    2378             msg = f"SKIPPED INLINING {code}: {e}"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     816                     self.instruction_pointer is not None
#     817                     and not self.output.should_exit
# --> 818                     and self.step()
#     819                 ):
#     820                     pass
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     779                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     780             )
# --> 781             getattr(self, inst.opname)(inst)
#     782
#     783             return inst.opname != "RETURN_VALUE"
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     468                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     469                 )
# --> 470                 return inner_fn(self, inst)
#     471             except Unsupported as excp:
#     472                 if self.should_compile_partial_graph() and self.has_backedge():
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION_KW(self, inst)
#    1262         kwargs = dict(zip(argnames, kwargs_list))
#    1263         assert len(kwargs) == len(argnames)
# -> 1264         self.call_function(fn, args, kwargs)
#    1265
#    1266     def LOAD_METHOD_SUPER(self, inst):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     650         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     651             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 652         self.push(fn.call_function(self, args, kwargs))
#     653
#     654     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/torch.py in call_function(self, tx, args, kwargs)
#     540                     fn_ = torch._refs.tensor
#     541
# --> 542             tensor_variable = wrap_fx_proxy(
#     543                 tx=tx,
#     544                 proxy=tx.output.create_proxy(
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/builder.py in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    1312     }
#    1313     if subclass_type is None:
# -> 1314         return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    1315     else:
#    1316         result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/builder.py in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    1397             # only allow_non_graph_fake in this instance because we handle the non-fake
#    1398             # cases properly below.
# -> 1399             example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    1400
#    1401         # Handle recursive calls here
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py in get_fake_value(node, tx, allow_non_graph_fake)
#    1523         elif isinstance(cause, ValueRangeError):
#    1524             raise UserError(UserErrorType.CONSTRAINT_VIOLATION, e.args[0]) from e
# -> 1525         raise TorchRuntimeError(str(e)).with_traceback(e.__traceback__) from None
#    1526
#    1527     if not allow_non_graph_fake:
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py in get_fake_value(node, tx, allow_non_graph_fake)
#    1484     try:
#    1485         with tx.fake_mode, enable_python_dispatcher():
# -> 1486             ret_val = wrap_fake_exception(
#    1487                 lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1488             )
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py in wrap_fake_exception(fn)
#    1025 def wrap_fake_exception(fn):
#    1026     try:
# -> 1027         return fn()
#    1028     except UnsupportedFakeTensorException as e:
#    1029         from .exc import unimplemented
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py in <lambda>()
#    1485         with tx.fake_mode, enable_python_dispatcher():
#    1486             ret_val = wrap_fake_exception(
# -> 1487                 lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1488             )
#    1489     except Unsupported:
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py in run_node(tracer, node, args, kwargs, nnmodule)
#    1590         except Exception as e:
#    1591             fn_str = f"Failed running {op} {node.target}(*{args}, **{kwargs}):\n"
# -> 1592             raise RuntimeError(fn_str + str(e)).with_traceback(e.__traceback__) from e
#    1593
#    1594     raise AssertionError(op)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py in run_node(tracer, node, args, kwargs, nnmodule)
#    1569         try:
#    1570             if op == "call_function":
# -> 1571                 return node.target(*args, **kwargs)
#    1572             elif op == "call_method":
#    1573                 return getattr(args[0], node.target)(*args[1:], **kwargs)
#
# TorchRuntimeError: Failed running call_function <built-in function scaled_dot_product_attention>(*(FakeTensor(..., size=(2, 16, s0, 128)), FakeTensor(..., size=(2, 16, 2048, 128), dtype=torch.float16), FakeTensor(..., size=(2, 16, 2048, 128), dtype=torch.float16)), **{'attn_mask': FakeTensor(..., size=(1, 1, s0, 2048), dtype=torch.bool), 'dropout_p': 0.0}):
# Expected query, key, and value to have the same dtype, but got query.dtype: float key.dtype: c10::Half and value.dtype: c10::Half instead.
#
# from user code:
#    File "/content/metavoice-src/metavoice-src/fam/llm/fast_inference_utils.py", line 131, in prefill
#     logits = model(x, spk_emb, input_pos)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/metavoice-src/metavoice-src/fam/llm/fast_model.py", line 160, in forward
#     x = layer(x, input_pos, mask)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/metavoice-src/metavoice-src/fam/llm/fast_model.py", line 179, in forward
#     h = x + self.attention(self.attention_norm(x), mask, input_pos)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/metavoice-src/metavoice-src/fam/llm/fast_model.py", line 222, in forward
#     y = F.scaled_dot_product_attention(q, k, v, attn_mask=mask, dropout_p=0.0)
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %%
wav_file = tts.synthesise(
  text="This is a demo of text to speech by MetaVoice-1B, an open-source foundational audio model.",
  spk_ref_path="assets/bria.mp3" # you can use any speaker reference file (WAV, OGG, MP3, FLAC, etc.)
)
display(Audio(wav_file, autoplay=True))
